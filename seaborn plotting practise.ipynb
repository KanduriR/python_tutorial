# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
from numpy.random import randn

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = sns.load_dataset('tips')

# %%
type(data.total_bill.values)
# Out:
# numpy.ndarray

# %%
plt.hist(data.total_bill.values,edgecolor='black',align='right',label='total_bill',color='hotpink')
plt.hist(data.tip.values,edgecolor='black',align='right',color='indianred',alpha=0.5)
plt.xlabel('total_bill',fontsize=15)
plt.ylabel('frequency',fontsize=15)
# Out:
# Text(0, 0.5, 'frequency')

# %%
sns.jointplot(data.total_bill.values,data.tip.values)

# %%
sns.jointplot(data.total_bill.values,data.tip.values,kind='hex')

# %%
dframe = randn(25)

# %%
sns.rugplot(dframe,cmap='Set1')
plt.hist(dframe,edgecolor='black',color='indianred')
# Out:
# (array([2., 1., 0., 6., 2., 1., 3., 6., 1., 3.]),
#  array([-1.6955761 , -1.36468508, -1.03379406, -0.70290304, -0.37201202,
#         -0.041121  ,  0.28977002,  0.62066104,  0.95155206,  1.28244308,
#          1.6133341 ]),
#  <a list of 10 Patch objects>)

# %%
sns.kdeplot(dframe,bw=0.75,lw=2)
sns.rugplot(dframe)

# %%
for bw in np.arange(0.5,2.0,0.25):
    sns.kdeplot(dframe,bw=bw,label=bw)

# %%
sns.kdeplot(data.total_bill.values,data.tip.values)

# %%
from scipy.stats import norm

# %%
data_normal = norm.rvs(loc=0, scale =1, size=1000)

# %%
ax = sns.distplot(data_normal,bins=100,hist=False,rug=True,color='skyblue',
                  axlabel='Normal Distribution',
                 rug_kws={'color':'pink','label':'Rug Plot'})
